# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
res_24 = []
res_2 = []
res_4 = []

datasets = {
    './AllData/sensor_readings_24.csv': res_24,
    './AllData/sensor_readings_4.csv': res_4,
    './AllData/sensor_readings_2.csv': res_2
}

classifiers = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(),
    'KNN': KNeighborsClassifier()
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for filename, result_var in datasets.items():
    print(f'\n==== Dataset: {filename} ====')
    df = pd.read_csv(filename)

    X = df.iloc[:, :-1]
    y = df['CLASS']

    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    results = []

    for name, model in classifiers.items():
        print(f'\n--- Classifier: {name} ---')
        y_pred = cross_val_predict(model, X_scaled, y, cv=cv)
        acc = accuracy_score(y, y_pred)

        results.append([name, acc])
        print(f'Accuracy (CV avg): {acc:.4f}')
        print('Classification Report:')
        print(classification_report(y, y_pred))

    results.sort(key=lambda x: x[1], reverse=True)
    result_var.append(results)
# Out:
# ==== Dataset: ./AllData/sensor_readings_24.csv ====
#
# --- Classifier: Logistic Regression ---
# Accuracy (CV avg): 0.6994
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.75      0.70      0.73      2205
#  Sharp-Right-Turn       0.68      0.78      0.73      2097
#  Slight-Left-Turn       0.61      0.53      0.57       328
# Slight-Right-Turn       0.66      0.54      0.60       826
#
#          accuracy                           0.70      5456
#         macro avg       0.68      0.64      0.65      5456
#      weighted avg       0.70      0.70      0.70      5456
#
#
# --- Classifier: Decision Tree ---
# Accuracy (CV avg): 0.9949
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       1.00      0.99      1.00      2205
#  Sharp-Right-Turn       1.00      1.00      1.00      2097
#  Slight-Left-Turn       0.99      0.98      0.99       328
# Slight-Right-Turn       0.99      1.00      0.99       826
#
#          accuracy                           0.99      5456
#         macro avg       0.99      0.99      0.99      5456
#      weighted avg       0.99      0.99      0.99      5456
#
#
# --- Classifier: Random Forest ---
# Accuracy (CV avg): 0.9940
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       1.00      0.99      0.99      2205
#  Sharp-Right-Turn       0.99      1.00      1.00      2097
#  Slight-Left-Turn       0.99      0.98      0.99       328
# Slight-Right-Turn       0.99      0.99      0.99       826
#
#          accuracy                           0.99      5456
#         macro avg       0.99      0.99      0.99      5456
#      weighted avg       0.99      0.99      0.99      5456
#
#
# --- Classifier: SVM ---
# Accuracy (CV avg): 0.8864
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.87      0.88      0.88      2205
#  Sharp-Right-Turn       0.90      0.93      0.92      2097
#  Slight-Left-Turn       0.95      0.87      0.91       328
# Slight-Right-Turn       0.86      0.78      0.82       826
#
#          accuracy                           0.89      5456
#         macro avg       0.90      0.87      0.88      5456
#      weighted avg       0.89      0.89      0.89      5456
#
#
# --- Classifier: KNN ---
# Accuracy (CV avg): 0.8605
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.85      0.87      0.86      2205
#  Sharp-Right-Turn       0.89      0.88      0.88      2097
#  Slight-Left-Turn       0.88      0.86      0.87       328
# Slight-Right-Turn       0.82      0.81      0.81       826
#
#          accuracy                           0.86      5456
#         macro avg       0.86      0.85      0.86      5456
#      weighted avg       0.86      0.86      0.86      5456
#
#
# ==== Dataset: ./AllData/sensor_readings_4.csv ====
#
# --- Classifier: Logistic Regression ---
# Accuracy (CV avg): 0.9410
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.96      0.91      0.93      2205
#  Sharp-Right-Turn       0.92      0.99      0.95      2097
#  Slight-Left-Turn       0.93      0.85      0.89       328
# Slight-Right-Turn       0.94      0.95      0.94       826
#
#          accuracy                           0.94      5456
#         macro avg       0.94      0.92      0.93      5456
#      weighted avg       0.94      0.94      0.94      5456
#
#
# --- Classifier: Decision Tree ---
# Accuracy (CV avg): 0.9998
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       1.00      1.00      1.00      2205
#  Sharp-Right-Turn       1.00      1.00      1.00      2097
#  Slight-Left-Turn       1.00      1.00      1.00       328
# Slight-Right-Turn       1.00      1.00      1.00       826
#
#          accuracy                           1.00      5456
#         macro avg       1.00      1.00      1.00      5456
#      weighted avg       1.00      1.00      1.00      5456
#
#
# --- Classifier: Random Forest ---
# Accuracy (CV avg): 0.9998
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       1.00      1.00      1.00      2205
#  Sharp-Right-Turn       1.00      1.00      1.00      2097
#  Slight-Left-Turn       1.00      1.00      1.00       328
# Slight-Right-Turn       1.00      1.00      1.00       826
#
#          accuracy                           1.00      5456
#         macro avg       1.00      1.00      1.00      5456
#      weighted avg       1.00      1.00      1.00      5456
#
#
# --- Classifier: SVM ---
# Accuracy (CV avg): 0.9545
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.98      0.92      0.95      2205
#  Sharp-Right-Turn       0.95      0.99      0.97      2097
#  Slight-Left-Turn       0.99      0.91      0.94       328
# Slight-Right-Turn       0.90      0.97      0.94       826
#
#          accuracy                           0.95      5456
#         macro avg       0.95      0.95      0.95      5456
#      weighted avg       0.96      0.95      0.95      5456
#
#
# --- Classifier: KNN ---
# Accuracy (CV avg): 0.9641
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.96      0.96      0.96      2205
#  Sharp-Right-Turn       0.97      0.98      0.97      2097
#  Slight-Left-Turn       0.97      0.93      0.95       328
# Slight-Right-Turn       0.95      0.95      0.95       826
#
#          accuracy                           0.96      5456
#         macro avg       0.96      0.96      0.96      5456
#      weighted avg       0.96      0.96      0.96      5456
#
#
# ==== Dataset: ./AllData/sensor_readings_2.csv ====
#
# --- Classifier: Logistic Regression ---
# Accuracy (CV avg): 0.9402
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.96      0.91      0.93      2205
#  Sharp-Right-Turn       0.92      0.99      0.95      2097
#  Slight-Left-Turn       0.96      0.83      0.89       328
# Slight-Right-Turn       0.93      0.95      0.94       826
#
#          accuracy                           0.94      5456
#         macro avg       0.94      0.92      0.93      5456
#      weighted avg       0.94      0.94      0.94      5456
#
#
# --- Classifier: Decision Tree ---
# Accuracy (CV avg): 0.9998
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       1.00      1.00      1.00      2205
#  Sharp-Right-Turn       1.00      1.00      1.00      2097
#  Slight-Left-Turn       1.00      1.00      1.00       328
# Slight-Right-Turn       1.00      1.00      1.00       826
#
#          accuracy                           1.00      5456
#         macro avg       1.00      1.00      1.00      5456
#      weighted avg       1.00      1.00      1.00      5456
#
#
# --- Classifier: Random Forest ---
# Accuracy (CV avg): 0.9998
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       1.00      1.00      1.00      2205
#  Sharp-Right-Turn       1.00      1.00      1.00      2097
#  Slight-Left-Turn       1.00      1.00      1.00       328
# Slight-Right-Turn       1.00      1.00      1.00       826
#
#          accuracy                           1.00      5456
#         macro avg       1.00      1.00      1.00      5456
#      weighted avg       1.00      1.00      1.00      5456
#
#
# --- Classifier: SVM ---
# Accuracy (CV avg): 0.9685
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.99      0.94      0.97      2205
#  Sharp-Right-Turn       0.97      1.00      0.98      2097
#  Slight-Left-Turn       0.97      0.95      0.96       328
# Slight-Right-Turn       0.91      0.97      0.94       826
#
#          accuracy                           0.97      5456
#         macro avg       0.96      0.97      0.96      5456
#      weighted avg       0.97      0.97      0.97      5456
#
#
# --- Classifier: KNN ---
# Accuracy (CV avg): 0.9863
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.99      0.99      0.99      2205
#  Sharp-Right-Turn       0.99      0.99      0.99      2097
#  Slight-Left-Turn       0.97      0.98      0.97       328
# Slight-Right-Turn       0.98      0.98      0.98       826
#
#          accuracy                           0.99      5456
#         macro avg       0.98      0.98      0.98      5456
#      weighted avg       0.99      0.99      0.99      5456

# %%
print(res_24)
print(res_2)
print(res_4)
# Out:
# [[['Decision Tree', 0.9948680351906158], ['Random Forest', 0.9939516129032258], ['SVM', 0.8863636363636364], ['KNN', 0.8605205278592375], ['Logistic Regression', 0.6994134897360704]]]
# [[['Decision Tree', 0.9998167155425219], ['Random Forest', 0.9998167155425219], ['KNN', 0.9862536656891495], ['SVM', 0.968475073313783], ['Logistic Regression', 0.9402492668621701]]]
# [[['Decision Tree', 0.9998167155425219], ['Random Forest', 0.9998167155425219], ['KNN', 0.9640762463343109], ['SVM', 0.9545454545454546], ['Logistic Regression', 0.9409824046920822]]]
