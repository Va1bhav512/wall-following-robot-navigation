# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
datasets = { './AllData/sensor_readings_24.csv': 24, './AllData/sensor_readings_4.csv': 4, './AllData/sensor_readings_2.csv':2}

# %%
classifiers = { 'Logistic Regression': LogisticRegression(max_iter=1000),
                'Decision Tree': DecisionTreeClassifier(),
                'Random Forest': RandomForestClassifier(),
                'SVM': SVC(),
                'KNN': KNeighborsClassifier()
              }

# %%
for filename, num_features in datasets.items():
    print(f'\n==== Dataset: {filename} ====')
    df = pd.read_csv(filename)
    X = df.iloc[:,:-1]
    y = df['CLASS']

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42,stratify=y)

    for name,model in classifiers.items():
        print(f'\n--- Classifier: {name} ---')
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)

        acc = accuracy_score(y_test,y_pred)
        print(f'Accuracy: {acc:.4f}')
        print('Classification Report:')
        print(classification_report(y_test,y_pred))
# Out:
# ==== Dataset: ./AllData/sensor_readings_24.csv ====
#
# --- Classifier: Logistic Regression ---
# Accuracy: 0.6932
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.75      0.72      0.74       441
#  Sharp-Right-Turn       0.67      0.76      0.71       420
#  Slight-Left-Turn       0.59      0.56      0.57        66
# Slight-Right-Turn       0.64      0.50      0.56       165
#
#          accuracy                           0.69      1092
#         macro avg       0.66      0.64      0.65      1092
#      weighted avg       0.69      0.69      0.69      1092
#
#
# --- Classifier: Decision Tree ---
# Accuracy: 0.9945
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Move-Forward       0.99      1.00      0.99       441
#  Sharp-Right-Turn       1.00      1.00      1.00       420
#  Slight-Left-Turn       1.00      0.97      0.98        66
# ...
